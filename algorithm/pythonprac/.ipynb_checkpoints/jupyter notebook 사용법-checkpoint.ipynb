# %%
x=3
y=7
print(x+y)
(x+y)*2
# Out:
# 10
# 20

# %%
x=3
y=7
print(x+y)
(x+y)*2
# Out:
# 10
# 20

# %% [markdown]
# # hello world
# ## hello word
# ### hello wrold
#
# 1. hellow owrd
# 2. hellow word
#  - hellow word
#
#  > hellow owrd
#  **word
#
# | name | age | city  |
# |------|-----|-------|
# | soo  | 27  | seoul |
# | jun  | 33  | chun  |

# %%
# !ls
# Out:
# 1.py                             jupyter notebook 사용법.ipynb

# %%
# !ls-al
# Out:
# zsh:1: command not found: ls-al

# %%
# !ls -al
# Out:
# total 16
# drwxr-xr-x  5 soolee  staff   160  4 20 00:30 .
# drwxr-xr-x  8 soolee  staff   256  4 20 00:07 ..
# drwxr-xr-x  3 soolee  staff    96  4 20 00:24 .ipynb_checkpoints
# -rw-r--r--@ 1 soolee  staff   214  4 19 23:58 1.py
# -rw-r--r--  1 soolee  staff  1856  4 20 00:30 jupyter notebook 사용법.ipynb

# %%
# !touch 001.py

# %%
# !ls
# Out:
# 001.py                           jupyter notebook 사용법.ipynb
# 1.py

# %%
# %run 001.py
# Out:
# helow word

# %%
# %%time
print(sum(range(1,10)))
# Out:
# 45
# CPU times: user 61 µs, sys: 14 µs, total: 75 µs
# Wall time: 69.9 µs

# %%
# %%timeit
print(sum(range(1,19)))
# Out:
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# ...

# %%
def f(x,y):
    return x+y

# %%
f(3,6)
# Out:
# 9

# %%
f?

# %%
f??

# %%
# f + shift + tab : 툴팁형태로 도움말 생성

# %%
import random
random.randint(1,10)
# Out:
# 5

# %%
## 이미지를 업로드 합니다.
